# %%
#i am importing the libraries 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# now we will read the file 
data=pd.read_csv(r"C:\Users\patha\OneDrive\Desktop\codtech\dataset\shopping_trends_updated.csv")

# %%
#want t know the head of the dataframe 
data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
# will check the info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
# Generate descriptive statistics for all numerical columns in the DataFrame

data.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
# Get the dimensions of the DataFrame (number of rows and columns)

data.shape
# Out:
# (3900, 18)

# %%
# Check for missing values in the DataFrame

data.isna()
# Out:
#       Customer ID    Age  Gender  Item Purchased  Category  \
# 0           False  False   False           False     False
# 1           False  False   False           False     False
# 2           False  False   False           False     False
# 3           False  False   False           False     False
# 4           False  False   False           False     False
# ...           ...    ...     ...             ...       ...
# 3895        False  False   False           False     False
# 3896        False  False   False           False     False
# 3897        False  False   False           False     False
# 3898        False  False   False           False     False
# 3899        False  False   False           False     False
#
#       Purchase Amount (USD)  Location   Size  Color  Season  Review Rating  \
# 0                     False     False  False  False   False          False
# 1                     False     False  False  False   False          False
# ...

# %%
# Get the count of missing values for each column in the DataFrame

data.isna().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
# Count the number of duplicate rows in the DataFrame

data.duplicated().sum()
# Out:
# 0

# %%
# Plot a histogram of the "Age" column with customized appearance

data["Age"].plot(kind="hist",color ="lightblue",edgecolor = "black")
plt.title("Histogram of Age")
plt.show()

# %%
# List all column names in the DataFrame
data.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
# Plot a bar chart for the distribution of "Gender" with customized appearance

data["Gender"].value_counts().plot(kind="bar",color ="lightpink", edgecolor ="black")
plt.title("Barplot of Gender Distribution")
plt.show()

# %%
# Calculate the average "Purchase Amount (USD)" for each "Category"

data.groupby("Category")["Purchase Amount (USD)"].mean()
# Out:
# Category
# Accessories    59.838710
# Clothing       60.025331
# Footwear       60.255426
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
# Calculate the average "Purchase Amount (USD)" for each "Category" and sort in descending order

data.groupby("Category")["Purchase Amount (USD)"].mean().sort_values(ascending=False)
# Out:
# Category
# Footwear       60.255426
# Clothing       60.025331
# Accessories    59.838710
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
# Calculate the average "Purchase Amount (USD)" for each "Category", sort in descending order, and get the top 2 categories

data.groupby("Category")["Purchase Amount (USD)"].mean().sort_values(ascending=False).head(2)
# Out:
# Category
# Footwear    60.255426
# Clothing    60.025331
# Name: Purchase Amount (USD), dtype: float64

# %%
# Calculate the average "Purchase Amount (USD)" for each "Category", sort in descending order, and get the bottom 3 categories

data.groupby("Category")["Purchase Amount (USD)"].mean().sort_values(ascending=False).tail(3)
# Out:
# Category
# Clothing       60.025331
# Accessories    59.838710
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
# Sort the DataFrame by "Review Rating" in descending order and return a new DataFrame

data.sort_values("Review Rating",ascending=False)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 776           777   49    Male          Shirt     Clothing
# 1664         1665   19    Male        Handbag  Accessories
# 1277         1278   19    Male         Blouse     Clothing
# 2632         2633   24    Male          Scarf  Accessories
# 965           966   43    Male          Boots     Footwear
# ...           ...  ...     ...            ...          ...
# 1451         1452   54    Male         Jacket    Outerwear
# 3473         3474   63  Female          Dress     Clothing
# 1449         1450   18    Male          Socks     Clothing
# 133           134   52    Male        Sweater     Clothing
# 870           871   66    Male         Hoodie     Clothing
#
#       Purchase Amount (USD)       Location Size     Color  Season  \
# 776                      60        Alabama    M    Maroon  Spring
# 1664                     53      Minnesota    M    Purple  Spring
# ...

# %%
# Sort the DataFrame by "Review Rating" in descending order and update the DataFrame in place

data.sort_values("Review Rating",ascending=False, inplace =True)

# %%
# Plot a pie chart for the "Subscription Status" with custom colors

data["Subscription Status"].value_counts().plot(kind="pie", colors=["blue","pink"],)
plt.title("Pie Chart of Subscription")
plt.show()

# %%
# Get the counts of all unique values in the "Color" column

data["Color"].value_counts()
# Out:
# Color
# Olive        177
# Yellow       174
# Silver       173
# Teal         172
# Green        169
# Black        167
# Violet       166
# Cyan         166
# Gray         159
# Maroon       158
# Orange       154
# Pink         153
# Charcoal     153
# Blue         152
# Magenta      152
# Purple       151
# Peach        149
# Red          148
# Lavender     147
# Indigo       147
# Beige        147
# Turquoise    145
# White        142
# Brown        141
# Gold         138
# Name: count, dtype: int64

# %%
# Get the counts of the top 5 most common values in the "Color" column

data["Color"].value_counts().head()
# Out:
# Color
# Olive     177
# Yellow    174
# Silver    173
# Teal      172
# Green     169
# Name: count, dtype: int64

# %%
# Plot a pie chart for the top 5 most common values in the "Color" column

data["Color"].value_counts().head().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
# Plot a scatter plot for "Previous Purchases" vs "Review Rating" for the entire DataFrame

data.plot(x="Previous Purchases",y="Review Rating",kind="scatter")
plt.title("Scatter Plot for previos purchases and Review Rating")
plt.show()

# %%
# Plot a scatter plot for "Previous Purchases" vs "Review Rating" using the first 15 rows

data.head(15).plot(x="Previous Purchases",y="Review Rating",kind="scatter")
plt.title("Scatter Plot for previos purchases and Review Rating")
plt.show()

# %%
# Calculate the total "Purchase Amount (USD)" for each "Season"

data.groupby("Season")["Purchase Amount (USD)"].sum()
# Out:
# Season
# Fall      60018
# Spring    58679
# Summer    55777
# Winter    58607
# Name: Purchase Amount (USD), dtype: int64

# %%
# Create a boxplot for "Purchase Amount (USD)" categorized by "Frequency of Purchases"

data.boxplot(column="Purchase Amount (USD)",by ="Frequency of Purchases",
             boxprops=dict(color="blue"),
             medianprops=dict(color="red"),
            whiskerprops=dict(color="black"),
            capprops=dict(color="black"),
            flierprops=dict(markeredgecolor="green"))
plt.grid(False)
plt.title("Box plotof purchase amount based on freqency")
plt.show()

# %%
# Get the count of occurrences for each "Payment Method"

data["Payment Method"].value_counts()
# Out:
# Payment Method
# PayPal           677
# Credit Card      671
# Cash             670
# Debit Card       636
# Venmo            634
# Bank Transfer    612
# Name: count, dtype: int64

# %%
# Get the maximum count of occurrences for any "Payment Method"

data["Payment Method"].value_counts().max()
# Out:
# 677

# %%
# Get the two least common "Payment Method" values, sorted by count in ascending order

data["Payment Method"].value_counts().sort_values(ascending=True).head(2)
# Out:
# Payment Method
# Bank Transfer    612
# Venmo            634
# Name: count, dtype: int64

# %%
# Get the two most common "Payment Method" values, sorted by count in ascending order

data["Payment Method"].value_counts().sort_values(ascending=True).tail(2)
# Out:
# Payment Method
# Credit Card    671
# PayPal         677
# Name: count, dtype: int64

# %%
# Create a pivot table to display the mean "Purchase Amount (USD)" for each "Location" and "Item Purchased"

pd.pivot_table(data, values = "Purchase Amount (USD)", index = "Location", columns = "Item Purchased", aggfunc="mean")
# Out:
# Item Purchased   Backpack       Belt     Blouse      Boots       Coat  \
# Location
# Alabama         74.000000  26.500000  52.000000  73.666667  54.500000
# Alaska          74.600000  76.750000  67.500000  56.000000  45.500000
# Arizona         48.600000  84.500000  61.000000        NaN  65.333333
# Arkansas        90.000000  55.000000  66.000000  50.000000  54.250000
# California      57.400000  61.666667  39.500000  62.500000  55.000000
# Colorado        57.000000  68.500000  55.000000        NaN  46.000000
# Connecticut     60.000000  47.666667  67.400000  64.250000  44.500000
# Delaware        33.000000  41.500000  42.200000  44.500000  57.500000
# Florida         59.000000  94.000000  31.000000  51.500000  51.166667
# Georgia         44.750000  62.000000  64.857143  85.000000  93.000000
# Hawaii          96.000000  44.000000  50.600000  74.000000  69.666667
# Idaho           53.250000  61.000000  65.000000  60.333333  65.250000
# ...

# %%
pd.pivot_table(data, values = "Purchase Amount (USD)", index = "Location", columns = "Item Purchased", aggfunc="mean").head()
# Out:
# Item Purchased  Backpack       Belt  Blouse      Boots       Coat      Dress  \
# Location
# Alabama             74.0  26.500000    52.0  73.666667  54.500000  55.200000
# Alaska              74.6  76.750000    67.5  56.000000  45.500000  74.500000
# Arizona             48.6  84.500000    61.0        NaN  65.333333  71.000000
# Arkansas            90.0  55.000000    66.0  50.000000  54.250000  62.800000
# California          57.4  61.666667    39.5  62.500000  55.000000  58.428571
#
# Item Purchased     Gloves    Handbag        Hat     Hoodie  ...      Scarf  \
# Location                                                    ...
# Alabama         85.000000  57.666667  76.000000  53.000000  ...  75.333333
# Alaska          66.333333  46.000000  52.666667  56.500000  ...  45.000000
# Arizona         87.000000  58.666667  87.000000  66.666667  ...  53.500000
# Arkansas        64.333333  50.000000  35.000000  55.250000  ...  67.500000
# ...

# %%
# Calculate the average "Purchase Amount (USD)" for each "Size" category

data.groupby("Size")["Purchase Amount (USD)"].mean()
# Out:
# Size
# L     58.563153
# M     59.924217
# S     61.037707
# XL    60.090909
# Name: Purchase Amount (USD), dtype: float64

# %%
# Calculate the total "Purchase Amount (USD)" for each "Payment Method"

data.groupby("Payment Method")["Purchase Amount (USD)"].sum()
# Out:
# Payment Method
# Bank Transfer    36544
# Cash             40002
# Credit Card      40310
# Debit Card       38742
# PayPal           40109
# Venmo            37374
# Name: Purchase Amount (USD), dtype: int64

# %%
# Get the maximum "Review Rating" for each group in the "Discount Applied" column

data.groupby("Discount Applied")["Review Rating"].max()
# Out:
# Discount Applied
# No     5.0
# Yes    5.0
# Name: Review Rating, dtype: float64

# %%
# Calculate the mean of "Review Rating" for each group in the "Discount Applied" column

data.groupby("Discount Applied")["Review Rating"].mean()
# Out:
# Discount Applied
# No     3.757715
# Yes    3.739654
# Name: Review Rating, dtype: float64

# %%
# Group the data by the 'Color' column and count the occurrences of each 'Category' within each color group.

data.groupby("Color")["Category"].value_counts()
# Out:
# Color   Category
# Beige   Clothing       65
#         Accessories    44
#         Footwear       24
#         Outerwear      14
# Black   Clothing       81
#                        ..
# White   Outerwear      15
# Yellow  Clothing       75
#         Accessories    56
#         Footwear       30
#         Outerwear      13
# Name: count, Length: 100, dtype: int64

# %%
# Group the data by the 'Frequency of Purchases' column and calculate the median of 'Previous Purchases' for each group.

data.groupby("Frequency of Purchases")["Previous Purchases"].median()
# Out:
# Frequency of Purchases
# Annually          24.0
# Bi-Weekly         24.0
# Every 3 Months    24.0
# Fortnightly       26.0
# Monthly           25.0
# Quarterly         28.0
# Weekly            26.0
# Name: Previous Purchases, dtype: float64

# %%
# Group the data by the 'Season' column and calculate the mean of 'Review Rating' for each season.

data.groupby("Season")["Review Rating"].mean()
# Out:
# Season
# Fall      3.729949
# Spring    3.790591
# Summer    3.725654
# Winter    3.752111
# Name: Review Rating, dtype: float64

# %%
#creating a bar graph to represent count of punchase in each season
data["Season"].value_counts().plot(kind="bar")
plt.xlabel("Season")
plt.ylabel("Count")
plt.title("count of punchases of each season")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#creating a pie char for distribution of purchase by its category
data["Category"].value_counts().plot(kind = "pie")
plt.title("distribution of purchases by category")
plt.show()

# %%
# Creating a boxplot of 'Review Rating' grouped by 'Gender.'

data.boxplot(column ="Review Rating", by= "Gender")
plt.xlabel("Gender")
plt.ylabel("Review Rating")
plt.title("Review rating distribution by gender")
plt.show()

# %%
# Plot a histogram of the 'Purchase Amount (USD)

data["Purchase Amount (USD)"].plot(kind = "hist",bins=10)
plt.xlabel("USD")
plt.title("histogram of purchase amount distribution")
plt.show()

# %%
# Group the data by the 'Color' column and calculate the mean of 'Review Rating' for each color.

data.groupby("Color")["Review Rating"].mean().plot(kind="bar")
plt.xlabel("color")
plt.ylabel("mean review rating")
plt.title("mean review rating for each color")
plt.show()

# %%
# Plot the mean 'Review Rating' for the top 5 most common colors as a bar chart.

data.groupby("Color")["Review Rating"].mean().head().plot(kind="bar")
plt.xlabel("color")
plt.ylabel("mean review rating")
plt.title("mean review rating for each color")
plt.show()

# %%
#plot the sum of purchase amount by purchase method

data.groupby("Payment Method")["Purchase Amount (USD)"].sum().plot(kind ="pie")
plt.ylbl
plt.title("sum of purchase amount by purchase method")
plt.show()

# %%
#plot the sum of purchase amount by purchase method

data.groupby("Payment Method")["Purchase Amount (USD)"].sum().plot(kind ="pie")
plt.title("sum of purchase amount by purchase method")
plt.ylabel("")
plt.show()

# %%
## Create a box plot to show the distribution of 'Purchase Amount (USD)' grouped by 'Frequency of Purchases'.

data.boxplot(column = "Purchase Amount (USD)", by = "Frequency of Purchases")
plt.xlabel("Frequency of Purchases")
plt.ylabel("Purchase Amount (USD)")
plt.title("Purchase amount distribution by frequency of purchase")
plt.show()

# %%
# Plot the sum of 'Purchase Amount (USD)' by season as a pie chart.

data.groupby("Season")["Purchase Amount (USD)"].sum().plot(kind = "pie")
plt.xlabel("Season")
plt.ylabel("sum of purchase amount(usd)")
plt.title("Sum of purchase amount by season")
plt.show()

# %% [markdown]
# # CONCLUSION

# %%
Data Overview:    
The analysis was conducted on a dataset containing various attributes like Age, Gender,Category, Purchase Amount, Review Rating, and Subscription Status among others.

Demographic Insights: 
The data revealed key demographic insights, such as the distribution of shoppers by age and gender, which were visualized through histograms and bar plots.

Purchase Behavior:

Category-wise Analysis: 
Categories with the highest and lowest average purchase amounts were identified, indicating consumer preferences.

Seasonal Impact:
Total purchase amounts were analyzed across different seasons, showing trends in shopping behavior over time.
Customer Engagement:

Subscription Status:
The distribution of customers based on subscription status was explored using a pie chart.

Review Analysis:
Relationships between the number of previous purchases and review ratings were investigated using scatter plots, highlighting how customer satisfaction correlates with purchase history.

Color Preferences:
Popular colors among products were identified, with a focus on the top 5, which was also visualized through a pie chart.

Purchase Frequency:
A box plot was used to assess the relationship between purchase frequency and the amount spent, offering insights into spending patterns.

Data Integrity:
Checks for missing values and duplicates were performed to ensure the reliability of the analysis.

This summary encapsulates the findings and visualizations from the dataset, offering a comprehensive view of shopping trends, customer preferences, and behaviors.
